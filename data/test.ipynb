# %%
import os
import sys
import pandas as pd
import matplotlib.pyplot as plt
import json
import requests

# %%
path="question\\"
cnpath="question\cn"
enpath="question\enscript"

# %%
import requests
import json

url = "https://api2.aigcbest.top/v1/chat/completions"

payload = json.dumps({
   "model": "gpt-4-turbo-2024-04-09",
   "stream": False,
   "messages": [
      {
         "role": "user",
         "content": [
            {
               "type": "text",
               "text": "这张图片是什么"
            },
            {
               "type": "image_url",
               "image_url": {
                  "url": "question/enscript/19-1 (2).png"
               }
            }
         ]
      }
   ],
   "temperature": 0.9,
   "max_tokens": 400
})
headers = {
   'Accept': 'application/json',
   'Authorization': 'sk-BpvUWdvp51TL56aeCb829561936946D3B07bC0B32d3a3c07',
   'User-Agent': 'Apifox/1.0.0 (https://apifox.com)',
   'Content-Type': 'application/json'
}

response = requests.request("POST", url, headers=headers, data=payload)
print(response.text)
# Out:
# 该报错并不常见，请联系客服查明原因，谢谢！

# %%
import requests

url = "https://api2.aigcbest.top/v1/models"

payload={}
headers = {
   'Authorization': 'sk-BpvUWdvp51TL56aeCb829561936946D3B07bC0B32d3a3c07',
   'User-Agent': 'Apifox/1.0.0 (https://apifox.com)'
}

response = requests.request("GET", url, headers=headers, data=payload)

print(response.text)
# Out:
# {"data":[{"id":"360GPT_S2_V9","object":"model","created":1626777600,"owned_by":"ai360","permission":[{"id":"modelperm-LwHkVFn8AcMItP432fKKDIKJ","object":"model_permission","created":1626777600,"allow_create_engine":true,"allow_sampling":true,"allow_logprobs":true,"allow_search_indices":false,"allow_view":true,"allow_fine_tuning":false,"organization":"*","group":null,"is_blocking":false}],"root":"360GPT_S2_V9","parent":null},{"id":"abab5.5-chat","object":"model","created":1626777600,"owned_by":"minimax","permission":[{"id":"modelperm-LwHkVFn8AcMItP432fKKDIKJ","object":"model_permission","created":1626777600,"allow_create_engine":true,"allow_sampling":true,"allow_logprobs":true,"allow_search_indices":false,"allow_view":true,"allow_fine_tuning":false,"organization":"*","group":null,"is_blocking":false}],"root":"abab5.5-chat","parent":null},{"id":"abab5.5s-chat","object":"model","created":1626777600,"owned_by":"minimax","permission":[{"id":"modelperm-LwHkVFn8AcMItP432fKKDIKJ","object":"m
# ...

# %%
import requests
import json

url = "https://api2.aigcbest.top/v1/chat/completions"

payload = json.dumps({
   "model": "gpt-4o",
   "stream": False,
   "messages": [
      {
         "role": "user",
         "content": [
            {
               "type": "text",
               "text": "这张图片是什么"
            },
            {
               "type": "image_url",
               "image_url": {
                  "url": "https://drive.google.com/uc?id=22-3-1 (2).png"
               }
            }
         ]
      }
   ],
   "temperature": 0.9,
   "max_tokens": 400
})
headers = {
   'Accept': 'application/json',
   'Authorization': 'sk-BpvUWdvp51TL56aeCb829561936946D3B07bC0B32d3a3c07',
   'User-Agent': 'Apifox/1.0.0 (https://apifox.com)',
   'Content-Type': 'application/json'
}

response = requests.request("POST", url, headers=headers, data=payload)
print(response.text)

# %%
# folder_path = enpath  # 文件夹路径
# txt_path='tmp.txt'
# # 使用os.listdir()函数获取文件夹下的所有文件和文件夹名
# file_names = os.listdir(folder_path)
# # print(file_names)
# # print(len(file_names))
# with open(txt_path,'w') as f:
#     for file_name in file_names:
#         f.write(file_name+':'+'\n')


# file_path = os.path.join(folder_path, file_names[109
                                                 
                                                 
#                                                  ])
# try:
#     # 使用Matplotlib库打开图像文件
#     image = plt.imread(file_path)
#     print(file_path)    
#     # 显示图像
#     plt.imshow(image)
#     plt.axis('off')  # 可选：关闭坐标轴
#     plt.show()
# except Exception as e:
#     print(f"无法打开文件: {file_path}")
#     print(str(e))
# Out:
# question\enscript\21-6-3 (6).png

# %%
sysPrompt="According to the displayed Scratch script and the given question, please choose a correct answer from the four options ABCD. You only need to find the correct option, and no analysis is required."

# %%
# i=109

# %%
# cnfile_path = os.path.join(cnpath, file_names[i]
#                            )
# i+=1
# print(i)
# # print(cnfile_path)
# try:
#     # 使用Matplotlib库打开图像文件
#     image = plt.imread(cnfile_path)
#     # print(cnfile_path)    
#     # 显示图像
#     plt.imshow(image)
#     plt.axis('off')  # 可选：关闭坐标轴
#     plt.show()
# except Exception as e:
#     print(f"无法打开文件: {cnfile_path}")
#     print(str(e))
# Out:
# 122

# %%
# # p=pd.read_json("question\prompt.json")
# # print(p)

# # 1. 读取现有的 JSON 文件
# file_path = 'question/prompt.json'  # 使用正斜杠或双反斜杠
# with open(file_path, 'r', encoding='utf-8') as f:
#     data = json.load(f)  # 读取 JSON 数据

# # 2. 添加新信息
# for file_name in file_names:
#     new_data = {
#         'name': file_name,
#         'prompt': ''
#     }
#     data.append(new_data)  # 将新信息添加到列表中

# # 3. 将更新后的数据写回 JSON 文件
# with open(file_path, 'w', encoding='utf-8') as f:
#     json.dump(data, f, ensure_ascii=False, indent=4)  # 写入 JSON 数据

# %%
# # 将prompt整理成文本文档，然后遍历将其加入json
# "prompt.txt"
# prompt=[]
# with open("prompt.txt","r", encoding="utf-8") as file:
#     for line in file:
#         prompt.append(line)

# %%
# len(prompt)
# Out:
# 122

# %%
# # 1. 读取现有的 JSON 文件
# file_path = 'question/prompt.json'  # 使用正斜杠或双反斜杠
# with open(file_path, 'r', encoding='utf-8') as f:
#     data = json.load(f)  # 读取 JSON 数据

# # 2. 修改特定记录
# # 假设我们要修改 name 为 'example.txt' 的记录
# for i,file_name in enumerate(file_names):
#     for entry in data:
#         if entry['name'] == file_name:  # 找到特定记录
#             entry['prompt'] = prompt[i]  # 修改数据
#             break  # 找到后退出循环

# # 3. 将更新后的数据写回 JSON 文件
# with open(file_path, 'w', encoding='utf-8') as f:
#     json.dump(data, f, ensure_ascii=False, indent=4)  # 写入 JSON 数据

# %%
# file_path="endata.json"
# with open(file_path, 'r', encoding='utf-8') as f:
#     data = json.load(f)  # 读取 JSON 数据

# with open('answer/data.json', 'r', encoding='utf-8') as f:
#     answer = json.load(f)  # 读取 JSON 数据

# with open('question/prompt.json', 'r', encoding='utf-8') as f:
#     prompt = json.load(f)  # 读取 JSON 数据

# # 2. 添加新信息
# for file_name in file_names:
#     for em in answer:
#         if(em["name"]==file_name):
#             l=em["label"]
#             t=em["type"]
#             break
    
#     for em in prompt:
#         if(em["name"]==file_name):
#             p=em["prompt"]
#             break
#     new_data = {
#         'name': file_name,
#         "label":l,
#         "type":t,
#         "prompt":p 
#     }
#     data.append(new_data)  # 将新信息添加到列表中


# # 3. 将更新后的数据写回 JSON 文件
# with open(file_path, 'w', encoding='utf-8') as f:
#     json.dump(data, f, ensure_ascii=False, indent=4)  # 写入 JSON 数据

# %%
'''
space
logic
geometry
color
math
string
'''

# %%
# file_path="endata.json"
# with open(file_path, 'r', encoding='utf-8') as f:
#     data = json.load(f)  # 读取 JSON 数据
# t="math"
# i=0
# for enp in data:
#     for tmp in enp["type"]:
#         if(tmp==t):
#             i+=1

# print("{} : {}".format(t,i))
# Out:
# math : 53

# %%
# i=0

# %%
# for emp in data:
#     if (emp["name"]==file_names[i]):
#         print("name: "+emp["name"])
#         print("type: ")
#         print(emp["type"])
#         break
# cnfile_path = os.path.join(cnpath, file_names[i])
# i+=1
# # print(cnfile_path)
# try:
#     # 使用Matplotlib库打开图像文件
#     image = plt.imread(cnfile_path)
#     # print(cnfile_path)    
#     # 显示图像
#     plt.imshow(image)
#     plt.axis('off')  # 可选：关闭坐标轴
#     plt.show()
# except Exception as e:
#     print(f"无法打开文件: {cnfile_path}")
#     print(str(e))
# Out:
# name: 19-2 (2).png
# type:
# ['program']
